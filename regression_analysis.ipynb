# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data=pd.read_csv("/Users/user/Desktop/Konya_data.csv")

# %%
data
# Out:
#     Year  Yield    SMN     SMT    VCI    TCI    VHI
# 0   1982  1.920  0.137  293.21  32.75  59.54  46.14
# 1   1983  1.755  0.116  291.13  21.55  69.41  45.48
# 2   1984  1.990  0.166  295.93  49.71  46.97  48.34
# 3   1985  1.418  0.132  298.42  24.22  39.33  31.78
# 4   1986  2.095  0.153  295.51  37.63  39.04  38.34
# 5   1987  1.908  0.133  293.11  32.34  55.74  44.04
# 6   1988  2.488  0.154  292.36  42.51  65.07  53.79
# 7   1989  1.387  0.124  294.74  24.76  39.57  32.16
# 8   1990  2.035  0.150  295.56  43.96  37.20  40.58
# 9   1991  2.328  0.158  293.46  45.26  50.37  47.82
# 10  1992  1.948  0.130  290.84  32.58  69.26  50.92
# 11  1993  1.816  0.145  292.64  43.40  56.92  50.16
# 12  1994  1.460  0.193  295.52  56.16  55.32  55.74
# 13  1995  1.860  0.145  296.32  31.43  44.70  38.07
# 14  1996  1.740  0.138  295.83  32.44  34.15  33.29
# 15  1997  2.220  0.177  295.08  59.28  47.17  53.22
# 16  1998  2.450  0.192  295.57  67.63  41.02  54.32
# ...

# %%
data.set_index('Year', inplace=True)

# %%
data.describe()
# Out:
#            Yield        SMN         SMT        VCI        TCI        VHI
# count  39.000000  39.000000   39.000000  39.000000  39.000000  39.000000
# mean    2.241333   0.158667  295.040000  45.854872  43.815897  44.835641
# std     0.575290   0.022578    1.908768  12.908392  12.459965   7.796337
# min     1.380000   0.116000  290.840000  21.550000  19.560000  29.750000
# 25%     1.838000   0.141500  293.580000  36.000000  36.375000  39.215000
# 50%     2.095000   0.156000  295.520000  45.260000  39.570000  46.140000
# 75%     2.631500   0.179000  296.330000  56.390000  52.335000  49.815000
# max     3.555000   0.201000  298.420000  70.510000  69.410000  58.930000

# %%
data.columns
# Out:
# Index(['Yield', 'SMN', 'SMT', 'VCI', 'TCI', 'VHI'], dtype='object')

# %%
plt.hist(data.SMN)
plt.show()

# %%
plt.hist(data.SMT)
plt.show()

# %%
plt.hist(data.VCI)
plt.show()

# %%
plt.hist(data.VHI)
plt.show()

# %%
plt.hist(data.TCI)
plt.show()

# %%
plt.hist(data.Yield)
plt.show()

# %%
data.Yield.plot(title="Yield by year")
plt.tight_layout(); plt.show()

# %%
data.SMN.plot(title="SMN by year")
plt.tight_layout(); plt.show()

# %%
data.SMT.plot(title="SMT by year")
plt.tight_layout(); plt.show()

# %%
data.VCI.plot(title="VCI by year")
plt.tight_layout(); plt.show()

# %%
data.TCI.plot(title="TCI by year")
plt.tight_layout(); plt.show()

# %%
data.VHI.plot(title="VHI by year")
plt.tight_layout(); plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39 entries, 1982 to 2020
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Yield   39 non-null     float64
#  1   SMN     39 non-null     float64
#  2   SMT     39 non-null     float64
#  3   VCI     39 non-null     float64
#  4   TCI     39 non-null     float64
#  5   VHI     39 non-null     float64
# dtypes: float64(6)
# memory usage: 2.1 KB

# %%
data.isnull().sum()
# Out:
# Yield    0
# SMN      0
# SMT      0
# VCI      0
# TCI      0
# VHI      0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
X=data.drop("Yield", axis=1)

# %%
y=pd.DataFrame(data["Yield"])

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_new=scaler.fit_transform(X)

# %%
data.columns
# Out:
# Index(['Yield', 'SMN', 'SMT', 'VCI', 'TCI', 'VHI'], dtype='object')

# %%
X_new
# Out:
# array([[-0.97219218, -0.97126666, -1.02849249,  1.27846705,  0.16949114],
#        [-1.91447075, -2.07522002, -1.90748741,  2.08095926,  0.08372936],
#        [ 0.32904966,  0.47236466,  0.30255698,  0.2564481 ,  0.45536376],
#        [-1.19654422,  1.79392422, -1.6979413 , -0.36473128, -1.69647739],
#        [-0.25426565,  0.249451  , -0.64550184, -0.38831008, -0.84405723],
#        [-1.15167381, -1.02434134, -1.06066998,  0.96950349, -0.10338726],
#        [-0.20939524, -1.42240145, -0.26251119,  1.72809035,  1.1635482 ],
#        [-1.55550748, -0.15922404, -1.65556119, -0.34521779, -1.64709939],
#        [-0.38887687,  0.27598834, -0.14871274, -0.53791349, -0.55298693],
#        [-0.02991361, -0.83857996, -0.04668654,  0.53288918,  0.38779387],
#        [-1.28628503, -2.2291366 , -1.04183437,  2.06876333,  0.79061437],
#        [-0.61322891, -1.27379234, -0.19266249,  1.0654448 ,  0.69185838],
#        [ 1.54055068,  0.25475847,  0.80876388,  0.93535488,  1.41693529],
# ...

# %%
X_new=pd.DataFrame(X_new, columns=['SMN', 'SMT', 'VCI', 'TCI', 'VHI'])

# %%
X_new
# Out:
#          SMN       SMT       VCI       TCI       VHI
# 0  -0.972192 -0.971267 -1.028492  1.278467  0.169491
# 1  -1.914471 -2.075220 -1.907487  2.080959  0.083729
# 2   0.329050  0.472365  0.302557  0.256448  0.455364
# 3  -1.196544  1.793924 -1.697941 -0.364731 -1.696477
# 4  -0.254266  0.249451 -0.645502 -0.388310 -0.844057
# 5  -1.151674 -1.024341 -1.060670  0.969503 -0.103387
# 6  -0.209395 -1.422401 -0.262511  1.728090  1.163548
# 7  -1.555507 -0.159224 -1.655561 -0.345218 -1.647099
# 8  -0.388877  0.275988 -0.148713 -0.537913 -0.552987
# 9  -0.029914 -0.838580 -0.046687  0.532889  0.387794
# 10 -1.286285 -2.229137 -1.041834  2.068763  0.790614
# 11 -0.613229 -1.273792 -0.192662  1.065445  0.691858
# 12  1.540551  0.254758  0.808764  0.935355  1.416935
# 13 -0.613229  0.679356 -1.132088  0.071883 -0.879142
# 14 -0.927322  0.419290 -1.052822 -0.785897 -1.500265
# 15  0.822624  0.021230  1.053627  0.272709  1.089481
# 16  1.495680  0.281296  1.708949 -0.227324  1.232418
# ...

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
r_sq=model.score(X,y)

# %%
r_sq
# Out:
# 0.49863284766923854

# %%
print(f"intercept: {model.intercept_}")
print(f"slope: {model.coef_}")
# Out:
# intercept: [62.16984324]
# slope: [[  9.29596099  -0.20764304 -13.15615208 -13.19514242  26.34712429]]

# %%
import statsmodels.api as sm

X_new= sm.add_constant(X_new, prepend=False)

# %%
X_new.shape
# Out:
# (39, 6)

# %%
y.shape
# Out:
# (39, 1)

# %%
print(type(X_new))
print(type(y))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
y.reset_index(inplace=True)

# %%
y
# Out:
#     Year  Yield
# 0   1982  1.920
# 1   1983  1.755
# 2   1984  1.990
# 3   1985  1.418
# 4   1986  2.095
# 5   1987  1.908
# 6   1988  2.488
# 7   1989  1.387
# 8   1990  2.035
# 9   1991  2.328
# 10  1992  1.948
# 11  1993  1.816
# 12  1994  1.460
# 13  1995  1.860
# 14  1996  1.740
# 15  1997  2.220
# 16  1998  2.450
# 17  1999  1.700
# 18  2000  2.370
# 19  2001  1.380
# 20  2002  1.980
# 21  2003  2.010
# 22  2004  2.124
# 23  2005  1.878
# 24  2006  2.488
# 25  2007  1.646
# 26  2008  1.771
# 27  2009  2.703
# 28  2010  2.249
# 29  2011  3.366
# 30  2012  2.596
# 31  2013  3.240
# 32  2014  2.667
# 33  2015  3.555
# 34  2016  2.790
# 35  2017  2.941
# 36  2018  3.008
# 37  2019  3.035
# 38  2020  3.097

# %%
data_new=pd.concat([X_new, y], axis=1).reindex(X_new.index)

# %%
data_new
# Out:
#          SMN       SMT       VCI       TCI       VHI  const  Year  Yield
# 0  -0.972192 -0.971267 -1.028492  1.278467  0.169491    1.0  1982  1.920
# 1  -1.914471 -2.075220 -1.907487  2.080959  0.083729    1.0  1983  1.755
# 2   0.329050  0.472365  0.302557  0.256448  0.455364    1.0  1984  1.990
# 3  -1.196544  1.793924 -1.697941 -0.364731 -1.696477    1.0  1985  1.418
# 4  -0.254266  0.249451 -0.645502 -0.388310 -0.844057    1.0  1986  2.095
# 5  -1.151674 -1.024341 -1.060670  0.969503 -0.103387    1.0  1987  1.908
# 6  -0.209395 -1.422401 -0.262511  1.728090  1.163548    1.0  1988  2.488
# 7  -1.555507 -0.159224 -1.655561 -0.345218 -1.647099    1.0  1989  1.387
# 8  -0.388877  0.275988 -0.148713 -0.537913 -0.552987    1.0  1990  2.035
# 9  -0.029914 -0.838580 -0.046687  0.532889  0.387794    1.0  1991  2.328
# 10 -1.286285 -2.229137 -1.041834  2.068763  0.790614    1.0  1992  1.948
# 11 -0.613229 -1.273792 -0.192662  1.065445  0.691858    1.0  1993  1.816
# ...

# %%
data_new=data_new.drop("const", axis=1)

# %%
import statsmodels.api as sm

import statsmodels.formula.api as smf

mod = smf.ols(formula='Yield ~ SMN + SMT + VCI +TCI +VHI', data=data_new)
res=mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Yield   R-squared:                       0.499
# Model:                            OLS   Adj. R-squared:                  0.423
# Method:                 Least Squares   F-statistic:                     6.564
# Date:                Sun, 31 Jul 2022   Prob (F-statistic):           0.000243
# Time:                        12:09:27   Log-Likelihood:                -19.807
# No. Observations:                  39   AIC:                             51.61
# Df Residuals:                      33   BIC:                             61.59
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.2413      0.070     32.021      0.000       2.099       2.384
# ...

# %%
print(res.params)
# Out:
# Intercept      2.241333
# SMN            0.207174
# SMT           -0.391228
# VCI         -167.633394
# TCI         -162.289495
# VHI          202.760496
# dtype: float64

# %%
mod1 = smf.ols(formula='Yield ~ SMN + SMT + VCI +TCI +VHI + SMN:SMT + SMN:VCI + SMN:TCI + SMN:VHI + SMT:VCI + SMT:TCI + SMT:VHI + VCI:TCI + VCI:VHI', data=data_new)
res1=mod1.fit()
print(res1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Yield   R-squared:                       0.621
# Model:                            OLS   Adj. R-squared:                  0.401
# Method:                 Least Squares   F-statistic:                     2.814
# Date:                Sun, 31 Jul 2022   Prob (F-statistic):             0.0125
# Time:                        12:09:27   Log-Likelihood:                -14.329
# No. Observations:                  39   AIC:                             58.66
# Df Residuals:                      24   BIC:                             83.61
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.3229      0.133     17.522      0.000       2.049       2.597
# ...

# %%
mod1 = smf.ols(formula='Yield ~ SMN + SMT + VCI +TCI +VHI + SMN:SMT + SMN:VCI + SMN:TCI + SMN:VHI + SMT:VCI + SMT:TCI + SMT:VHI + VCI:TCI + VCI:VHI + SMN:SMT:VCI +SMN:SMT:TCI +SMN:SMT:VHI + SMT:VCI:TCI + SMT:VCI:VHI +VCI:TCI:VHI + SMN:SMT:VCI:TCI + SMN:SMT:VCI:VHI + SMT:VCI:TCI:VHI + SMN:SMT:VCI:TCI:VHI', data=data_new)
res1=mod1.fit()
print(res1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Yield   R-squared:                       0.843
# Model:                            OLS   Adj. R-squared:                  0.573
# Method:                 Least Squares   F-statistic:                     3.127
# Date:                Sun, 31 Jul 2022   Prob (F-statistic):             0.0152
# Time:                        12:09:27   Log-Likelihood:                 2.8050
# No. Observations:                  39   AIC:                             44.39
# Df Residuals:                      14   BIC:                             85.98
# Df Model:                          24
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               2.2860      0.137     16.740      0.000       1.993       2.579
# ...

# %%
mod1 = smf.ols(formula='Yield ~ SMN + SMT + VCI +TCI +VHI + SMN:SMT + SMN:TCI + SMN:VHI + SMT:VCI + SMT:TCI + SMT:VHI + VCI:TCI + VCI:VHI + SMN:SMT:VCI +SMN:SMT:TCI +SMN:SMT:VHI + SMT:VCI:TCI + SMT:VCI:VHI +VCI:TCI:VHI + SMN:SMT:VCI:TCI + SMN:SMT:VCI:VHI + SMT:VCI:TCI:VHI + SMN:SMT:VCI:TCI:VHI', data=data_new)
res1=mod1.fit()
print(res1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Yield   R-squared:                       0.843
# Model:                            OLS   Adj. R-squared:                  0.602
# Method:                 Least Squares   F-statistic:                     3.495
# Date:                Sun, 31 Jul 2022   Prob (F-statistic):            0.00769
# Time:                        12:09:27   Log-Likelihood:                 2.8006
# No. Observations:                  39   AIC:                             42.40
# Df Residuals:                      15   BIC:                             82.32
# Df Model:                          23
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               2.2861      0.132     17.327      0.000       2.005       2.567
# ...

# %%
mod1 = smf.ols(formula='Yield ~ SMN + SMT + VCI +TCI +VHI + SMN:SMT + SMN:TCI +SMT:VCI + SMT:TCI + SMT:VHI + VCI:TCI + VCI:VHI + SMN:SMT:VCI +SMN:SMT:TCI +SMN:SMT:VHI + SMT:VCI:TCI + SMT:VCI:VHI +VCI:TCI:VHI + SMN:SMT:VCI:TCI + SMN:SMT:VCI:VHI + SMT:VCI:TCI:VHI + SMN:SMT:VCI:TCI:VHI', data=data_new)
res1=mod1.fit()
print(res1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Yield   R-squared:                       0.843
# Model:                            OLS   Adj. R-squared:                  0.626
# Method:                 Least Squares   F-statistic:                     3.897
# Date:                Sun, 31 Jul 2022   Prob (F-statistic):            0.00369
# Time:                        12:09:27   Log-Likelihood:                 2.7989
# No. Observations:                  39   AIC:                             40.40
# Df Residuals:                      16   BIC:                             78.66
# Df Model:                          22
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               2.2854      0.127     18.059      0.000       2.017       2.554
# ...

# %%
mod1 = smf.ols(formula='Yield ~ SMT + VCI +TCI +VHI + SMN:SMT + SMN:TCI +SMT:VCI + SMT:TCI + SMT:VHI + VCI:TCI + VCI:VHI + SMN:SMT:VCI +SMN:SMT:TCI +SMN:SMT:VHI + SMT:VCI:TCI + SMT:VCI:VHI +VCI:TCI:VHI + SMN:SMT:VCI:TCI + SMN:SMT:VCI:VHI + SMT:VCI:TCI:VHI + SMN:SMT:VCI:TCI:VHI', data=data_new)
res1=mod1.fit()
print(res1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Yield   R-squared:                       0.842
# Model:                            OLS   Adj. R-squared:                  0.648
# Method:                 Least Squares   F-statistic:                     4.330
# Date:                Sun, 31 Jul 2022   Prob (F-statistic):            0.00170
# Time:                        12:09:27   Log-Likelihood:                 2.7701
# No. Observations:                  39   AIC:                             38.46
# Df Residuals:                      17   BIC:                             75.06
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               2.2806      0.119     19.164      0.000       2.030       2.532
# ...

# %%
mod1 = smf.ols(formula='Yield ~ SMT + TCI +VHI + SMN:SMT + SMN:TCI +SMT:VCI + SMT:TCI + SMT:VHI + VCI:TCI + VCI:VHI + SMN:SMT:VCI +SMN:SMT:TCI +SMN:SMT:VHI + SMT:VCI:TCI + SMT:VCI:VHI +VCI:TCI:VHI + SMN:SMT:VCI:TCI + SMN:SMT:VCI:VHI + SMT:VCI:TCI:VHI + SMN:SMT:VCI:TCI:VHI', data=data_new)
res1=mod1.fit()
print(res1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Yield   R-squared:                       0.838
# Model:                            OLS   Adj. R-squared:                  0.659
# Method:                 Least Squares   F-statistic:                     4.665
# Date:                Sun, 31 Jul 2022   Prob (F-statistic):           0.000903
# Time:                        12:09:27   Log-Likelihood:                 2.2577
# No. Observations:                  39   AIC:                             37.48
# Df Residuals:                      18   BIC:                             72.42
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               2.2894      0.116     19.656      0.000       2.045       2.534
# ...

# %%
mod1 = smf.ols(formula='Yield ~ TCI +VHI + SMN:SMT + SMN:TCI +SMT:VCI + SMT:TCI + SMT:VHI + VCI:TCI + VCI:VHI + SMN:SMT:VCI +SMN:SMT:VHI + SMT:VCI:TCI + SMT:VCI:VHI +VCI:TCI:VHI + SMN:SMT:VCI:TCI + SMN:SMT:VCI:VHI + SMT:VCI:TCI:VHI + SMN:SMT:VCI:TCI:VHI', data=data_new)
res1=mod1.fit()
print(res1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Yield   R-squared:                       0.828
# Model:                            OLS   Adj. R-squared:                  0.673
# Method:                 Least Squares   F-statistic:                     5.339
# Date:                Sun, 31 Jul 2022   Prob (F-statistic):           0.000260
# Time:                        12:09:27   Log-Likelihood:                 1.0246
# No. Observations:                  39   AIC:                             35.95
# Df Residuals:                      20   BIC:                             67.56
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               2.2968      0.113     20.403      0.000       2.062       2.532
# ...

# %%
mod1 = smf.ols(formula='Yield ~ TCI +VHI + SMN:SMT + SMN:TCI + SMT:TCI + SMT:VHI + VCI:TCI + VCI:VHI + SMN:SMT:VCI +SMN:SMT:TCI +SMN:SMT:VHI + SMT:VCI:TCI + SMT:VCI:VHI +VCI:TCI:VHI + SMN:SMT:VCI:TCI + SMN:SMT:VCI:VHI + SMT:VCI:TCI:VHI + SMN:SMT:VCI:TCI:VHI', data=data_new)
res1=mod1.fit()
print(res1.summary()) #en iyi model
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Yield   R-squared:                       0.815
# Model:                            OLS   Adj. R-squared:                  0.648
# Method:                 Least Squares   F-statistic:                     4.891
# Date:                Sun, 31 Jul 2022   Prob (F-statistic):           0.000478
# Time:                        12:09:27   Log-Likelihood:               -0.37770
# No. Observations:                  39   AIC:                             38.76
# Df Residuals:                      20   BIC:                             70.36
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               2.3160      0.116     19.894      0.000       2.073       2.559
# ...
